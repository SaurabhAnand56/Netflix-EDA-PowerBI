# %% [markdown]
# ![image.png](attachment:78993f82-2184-490a-a026-9827b6d76c4b.png)

# %% [markdown]
# <a id='top'></a>
# <div class="list-group" id="list-tab" role="tablist"></div>
#
# <h2 style="text-align: left; background-color:#000000; font-family: Times New Roman; color: #E50914; padding: 13px; line-height:0.9;border-radius:2px; margin-bottom: 0em; text-align: center; font-size: 25px; border-radius: 100px 100px;">TABLE OF CONTENTS</h2>
#
# * &nbsp; **[Import](#IMPORT-AND-LOAD-DATA)**
# * &nbsp; **[Data Cleaning](#DATA-CLEANING)**
# * &nbsp; **[Tableu Dashboard](#Tableau-Dashboard)**

# %%
import numpy as np 
import pandas as pd

import plotly.express as px

# %%
data = pd.read_csv('/kaggle/input/netflix-shows/netflix_titles.csv')
data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %% [markdown]
# <a id='top'></a>
# <div class="list-group" id="list-tab" role="tablist"></div>
#
# <h2 style="text-align: left; background-color:#000000; font-family: Times New Roman; color: #E50914; padding: 13px; line-height:0.9;border-radius:2px; margin-bottom: 0em; text-align: center; font-size: 25px; border-radius: 100px 100px;">DATA CLEANING</h2>

# %% [markdown]
# <h2 style = "font-family:garamond; font-size:30px; background-color: white; color : #E50914; border-radius: 100px 100px; text-align:left">Data Info</h2>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %% [markdown]
# <h2 style = "font-family:garamond; font-size:30px; background-color: white; color : #E50914; border-radius: 100px 100px; text-align:left">Drop</h2>

# %%
# Drop Columns 
data.drop(columns=['show_id', 'cast', 'director', 'description'], inplace=True)

# Replacments
data['country'] = data['country'].fillna(data['country'].mode()[0])

# Drop the rest
data.dropna(inplace=True)

# %% [markdown]
# <h2 style = "font-family:garamond; font-size:30px; background-color: white; color : #E50914; border-radius: 100px 100px; text-align:left">Added Date</h2>

# %%
# Change Data Type to DateTime
data["date_added"] = pd.to_datetime(data['date_added'])

# %% [markdown]
# <h2 style = "font-family:garamond; font-size:30px; background-color: white; color : #E50914; border-radius: 100px 100px; text-align:left">Country Column</h2>

# %%
# Let's leave only first country from each list
data['principal_country'] = data['country'].apply(lambda x: x.split(",")[0])

# %% [markdown]
# <h2 style = "font-family:garamond; font-size:30px; background-color: white; color : #E50914; border-radius: 100px 100px; text-align:left">Rating Ages</h2>

# %%
ratings_ages = {
    'TV-PG': 'Older Kids',
    'TV-MA': 'Adults',
    'TV-Y7-FV': 'Older Kids',
    'TV-Y7': 'Older Kids',
    'TV-14': 'Teens',
    'R': 'Adults',
    'TV-Y': 'Kids',
    'NR': 'Adults',
    'PG-13': 'Teens',
    'TV-G': 'Kids',
    'PG': 'Older Kids',
    'G': 'Kids',
    'UR': 'Adults',
    'NC-17': 'Adults'
}

# Replace Rating values with age targets, they are based on
data['ages'] = data['rating'].replace(ratings_ages)
data['ages'].unique()
# Out:
# array(['Teens', 'Adults', 'Older Kids', 'Kids'], dtype=object)

# %% [markdown]
# <h2 style = "font-family:garamond; font-size:30px; background-color: white; color : #E50914; border-radius: 100px 100px; text-align:left">Final Dataset</h2>

# %%
data.head()
# Out:
#       type                  title        country date_added  release_year  \
# 0    Movie   Dick Johnson Is Dead  United States 2021-09-25          2020
# 1  TV Show          Blood & Water   South Africa 2021-09-24          2021
# 2  TV Show              Ganglands  United States 2021-09-24          2021
# 3  TV Show  Jailbirds New Orleans  United States 2021-09-24          2021
# 4  TV Show           Kota Factory          India 2021-09-24          2021
#
#   rating   duration                                          listed_in  \
# 0  PG-13     90 min                                      Documentaries
# 1  TV-MA  2 Seasons    International TV Shows, TV Dramas, TV Mysteries
# 2  TV-MA   1 Season  Crime TV Shows, International TV Shows, TV Act...
# 3  TV-MA   1 Season                             Docuseries, Reality TV
# 4  TV-MA  2 Seasons  International TV Shows, Romantic TV Shows, TV ...
#
#   principal_country    ages
# 0     United States   Teens
# 1      South Africa  Adults
# ...

# %% [markdown]
# <h2 style = "font-family:garamond; font-size:30px; background-color: white; color : #E50914; border-radius: 100px 100px; text-align:left">Download the Data</h2>

# %%
data.to_csv('/kaggle/working/netflix_title_cleaned.csv')

# %% [markdown]
# <a id='top'></a>
# <div class="list-group" id="list-tab" role="tablist"></div>
#
# <h2 style="text-align: left; background-color:#000000; font-family: Times New Roman; color: #E50914; padding: 13px; line-height:0.9;border-radius:2px; margin-bottom: 0em; text-align: center; font-size: 25px; border-radius: 100px 100px;">TABLEAU DASHBOARD</h2>

# %% [markdown]
# [![image.png](attachment:915a2f03-94ce-48ca-97e3-1e9545958167.png)](https://public.tableau.com/views/NetflixData_16737501303220/Dashboard1?:language=en-US&publish=yes&:display_count=n&:origin=viz_share_link)

# %% [markdown]
# <h2 style = "font-family:garamond; font-size:30px; background-color: white; color : #E50914; border-radius: 100px 100px; text-align:left">Link for my Tableau Dashboard: <a href="https://public.tableau.com/views/NetflixData_16737501303220/Dashboard1?:language=en-US&publish=yes&:display_count=n&:origin=viz_share_lin"> link</a></h2>

# %% [markdown]
# <a id='top'></a>
# <div class="list-group" id="list-tab" role="tablist"></div>
#
# <h2 style="text-align: left; background-color:#000000; font-family: Times New Roman; color: #E50914; padding: 13px; line-height:0.9;border-radius:2px; margin-bottom: 0em; text-align: center; font-size: 25px; border-radius: 100px 100px;">REFERENCE</h2>

# %% [markdown]
# <h2 style = "font-family:garamond; font-size:30px; background-color: white; color : #E50914; border-radius: 100px 100px; text-align:left">Thanks to:</h2>

# %% [markdown]
# * https://www.kaggle.com/code/bhartiprasad17/netflix-movies-and-tv-shows-eda
#
# * https://public.tableau.com/views/NetflixUsageV2/NetflixUsage?:language=en-US&:display_count=n&:origin=viz_share_link

# %% [markdown]
# <h2 style = "font-family:garamond; font-size:30px; background-color: white; color : #E50914; border-radius: 100px 100px; text-align:left">Check out my other works: </h2>

# %% [markdown]
# * [Superstore Dataset Complete Analysis | Plotly](https://www.kaggle.com/code/zhukovoleksiy/superstore-dataset-complete-analysis-plotly)
#
# * [Titanic with XGBClassifier](https://www.kaggle.com/code/zhukovoleksiy/titanic-with-xgbclassifier)
#
# * [Matplotlib Common Plot Types](https://www.kaggle.com/code/zhukovoleksiy/matplotlib-common-plot-types)
#
# * [Mental Disorders | Data Cleaning + Dashboard](https://www.kaggle.com/code/zhukovoleksiy/mental-disorders-data-cleaning-dashboard)
